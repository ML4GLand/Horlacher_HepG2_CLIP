# %%
import pandas as pd

# %%
results_df = pd.read_csv("/cellar/users/aklie/data/datasets/Horlacher_HepG2_CLIP/bin/dataset_preparation/bpnet.64.8.log", sep="\t")

# %%
results_df
# Out:
#     Epoch  Iteration  Training Time  Validation Time  Training MNLL  \
# 0       0          0       0.056589         0.007304     117.786057
# 1       1        100       3.039360         0.007490      85.644272
# 2       3        200       2.734786         0.007396     105.844429
# 3       5        300       2.728283         0.007399     101.363815
# 4       7        400       2.694736         0.007395     127.645233
# 5       9        500       2.500578         0.007361      96.829727
# 6      11        600       2.363187         0.007360      92.389999
# 7      13        700       2.256683         0.007387     118.143730
# 8      15        800       2.193658         0.007384     101.824860
# 9      17        900       2.017582         0.007372      88.245071
# 10     19       1000       1.857460         0.007357      92.930161
# 11     21       1100       1.821225         0.007355      80.050446
# 12     23       1200       1.669358         0.007356     100.026497
# ...
